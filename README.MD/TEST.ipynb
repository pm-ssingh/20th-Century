# %%
1+1
# Out:
# 2

# %%
"I AM A PM" * 100
# Out:
# 'I AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PMI AM A PM'
